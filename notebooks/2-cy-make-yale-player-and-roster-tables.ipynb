# %% [markdown]
# ## Notebook Overview
#
# Take the data from notebook 1, and flatten the nested data structures so it can be put into sql-database-friendly form.
#
# Belatedly noticing that in some sports, they list the coaches as a second table... decide later whether we want to gather that as well.

# %%
# Use w/ Anaconda Distribution
# For data manipulation
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
PROJ_ROOT = os.pardir

# For Scraping
from bs4 import BeautifulSoup
import requests
import time

# For munging
import re
import json

# Backoff time for large scrapes
THROTTLE_TIME = .05

# ipython magics
# %load_ext watermark
# %matplotlib inline

# %%
import missingno as msno

# %%
# %watermark -a "Cameron Yick" -d -t -v -p pandas,seaborn,matplotlib,bs4 -g
# Out:
# Cameron Yick 2016-11-05 21:41:16
#
# CPython 2.7.12
# IPython 4.0.1
#
# pandas 0.17.1
# seaborn 0.7.1
# matplotlib 1.5.0
# bs4 4.4.1
# Git hash: ed1904a929cd8dcb812e0a7193202e2ab046079e

# %%
RAW_PATH = os.path.join(PROJ_ROOT, "data", "raw", "sports.json")
RAW_PICK = os.path.join(PROJ_ROOT, "data", "raw", "sports.p")

# %%
sports = pd.read_pickle(RAW_PICK)

# %% [markdown]
# ## Can we check how the size of a roster has changed each year, for each sport?
#
# A roster is a collection of players for 1 season.

# %%
sports.columns
# Out:
# Index([u'href', u'name', u'gender', u'currentRoster', u'seasons', u'nSeasons',
#        u'rosters'],
#       dtype='object')

# %% [markdown]
# We have 33 collections of rosters, 1 for each sport

# %%
sports.rosters
# Out:
# 0     {u'2008-09': [[{'link': '/sports/m-basebl/2008...
# 1     {u'2008-09': [[{'link': '/sports/m-baskbl/2008...
# 2     {u'2008-09': [[{'link': '/sports/m-crewhvy/200...
# 3     {u'2012-13': [[{'link': '/sports/m-crewlt/2012...
# 4     {u'2012-13': [[{'link': '/sports/m-xc/2012-13/...
# 5     {u'2008-09': [[{'link': '/sports/m-fenc/2008-0...
# 6     {u'2008-09': [[{'link': '/sports/m-footbl/2008...
# 7     {u'2008-09': [[{'link': '/sports/m-golf/2008-0...
# 8     {u'2012-13': [[{'link': '/sports/m-hockey/2012...
# 9     {u'2012-13': [[{'link': '/sports/m-lacros/2012...
# 10    {u'2008-09': [[{'link': '/sports/c-sail/2008-0...
# 11    {u'2008-09': [[{'link': '/sports/m-soccer/2008...
# 12    {u'2012-13': [[{'link': '/sports/m-squash/2012...
# 13    {u'2012-13': [[{'link': '/sports/m-swim/2012-1...
# 14    {u'2012-13': [[{'link': '/sports/m-tennis/2012...
# 15    {u'2008-09': [[{'link': '/sports/m-track/2008-...
# 16    {u'2008-09': [[{'link': '/sports/w-baskbl/2008...
# 17    {u'2012-13': [[{'link': '/sports/w-crew/2012-1...
# 18    {u'2008-09': [[{'link': '/sports/w-xc/2008-09/...
# 19    {u'2008-09': [[{'link': '/sports/w-fenc/2008-0...
# 20    {u'2012-13': [[{'link': '/sports/w-fieldh/2012...
# 21    {u'2008-09': [[{'link': '/sports/w-golf/2008-0...
# 22    {u'2008-09': [[{'link': '/sports/w-gym/2008-09...
# 23    {u'2008-09': [[{'link': '/sports/w-hockey/2008...
# 24    {u'2012-13': [[{'link': '/sports/w-lacros/2012...
# 26    {u'2012-13': [[{'link': '/sports/w-sail/2012-1...
# 27    {u'2008-09': [[{'link': '/sports/w-soccer/2008...
# 28    {u'2008-09': [[{'link': '/sports/w-softbl/2008...
# 29    {u'2012-13': [[{'link': '/sports/w-squash/2012...
# 30    {u'2012-13': [[{'link': '/sports/w-swim/2012-1...
# 31    {u'2012-13': [[{'link': '/sports/w-tennis/2012...
# 32    {u'2012-13': [[{'link': '/sports/w-track/2012-...
# 33    {u'2008-09': [[{'link': '/sports/w-volley/2008...
# Name: rosters, dtype: object

# %%
# The top entry for every table describes what metadata is available for players in that table.
sports.iloc[0]['rosters']['2016-17'][-1:]
# Out:
# [[u'',
#   u'',
#   {'link': '/sports/m-basebl/2016-17/bios/stiegler_alex_3dje',
#    'name': u'Alex Stiegler'},
#   u'RHP/SS',
#   u'Freshman',
#   u'R/R',
#   u'',
#   u'',
#   u'- / -']]

# %% [markdown]
# Before we can do anything fun, we need to attach these labels as keys onto the cell row entries.

# %%
def getFieldnames(rows):
    'Given an array of rows from a table, return a list of what to name all the keys in that table.'
    header = rows[0]
    names = []
    for fieldName in header:
        if type(fieldName) is dict:
            names.append(fieldName['name'])
        else:
            names.append(fieldName)
            
    return names

# %%
rosters = []

for i, row in sports.iterrows(): # for each sport
    sportName = row['name']
    
    for season, roster in row['rosters'].iteritems():    # check for each season
        nRoster = {}
        players = [] # new array of players for every season
        
        fieldNames = getFieldnames(roster)
           
        nRoster['sport'] = sportName             # this is the foreign key, when combined with the season
        nRoster['season'] = season
        nRoster['metadata'] = fieldNames
       
        #         print "{0} {1} {2}".format(season, sportName, len(roster[1:]))
        
        for person in roster[1:]: # iterate throw the tail rows of the roster, and drop the last entry
            nPlayer = {}
            nPlayer['sport'] = sportName
            nPlayer['season'] = season

            for i, val in enumerate(fieldNames):
                
                fieldVal = person[i+1] # do to skip the headshot column
                
                if type(fieldVal) is dict:
                    nPlayer[val + '_link'] = fieldVal['link']
                    nPlayer[val] = fieldVal['name']
                else:
                    nPlayer[val] = fieldVal
                    
            players.append(nPlayer)
        
        nRoster['players'] = players
        
        rosters.append(nRoster)

# %%
len(rosters)
# Out:
# 328

# %%
players = []

for roster in rosters:
    players.extend(roster['players'])

# %%
len(players)
# Out:
# 8702

# %%
pdf = pd.DataFrame(players)

# %%
print pdf.columns
pdf.shape
# Out:
# Index([                 u'B/T',                  u'Cl.',
#                      u'Events', u'Hometown/High School',
#                         u'Ht.',                 u'Name',
#                   u'Name_link',                  u'No.',
#                        u'Pos.',               u'Weapon',
#                         u'Wt.',               u'season',
#                       u'sport'],
#       dtype='object')
# (8702, 13)

# %%
pdf.head()
# Out:
#   B/T        Cl. Events                   Hometown/High School   Ht.  \
# 0       Freshman    NaN            Manhasset, N.Y. / Chaminade  5-11
# 1         Junior    NaN      Sunrise, Fla. / Pine Crest School   6-2
# 2      Sophomore    NaN  Bloomington, Ind. / Bloomington North   5-9
# 3         Junior    NaN         Suffern, N.Y. / Don Bosco Prep  5-11
# 4         Junior    NaN                Atlanta, Ga. / Chamblee   6-7
#
#              Name                                   Name_link No. Pos. Weapon  \
# 0    Ryan Brenner    /sports/m-basebl/mtt/brenner_ryan00.html  11    C    NaN
# 1    Joe Castaldi    /sports/m-basebl/mtt/castaldi_joe00.html  34    P    NaN
# 2     Gant Elmore     /sports/m-basebl/mtt/elmore_gant00.html   1   IF    NaN
# 3  Chris Finneran  /sports/m-basebl/mtt/finneran_chris00.html  40    P    NaN
# 4   Robert Gruber   /sports/m-basebl/mtt/gruber_robert00.html  29    P    NaN
#
#    Wt.   season     sport
# 0  180  2008-09  Baseball
# 1  190  2008-09  Baseball
# 2  170  2008-09  Baseball
# 3  175  2008-09  Baseball
# 4  220  2008-09  Baseball

# %%
# beware inconsistency in high school name
pdf[pdf['Name'] == 'Emily Waligurski']
# Out:
#       B/T  Cl.    Events                Hometown/High School  Ht.  \
# 5813  NaN  So.       NaN              Hurley, N.Y. / Onteora  NaN
# 5869  NaN  Sr.       NaN  Hurley, N.Y. / Onteora High School  NaN
# 5950  NaN  Jr.       NaN  Hurley, N.Y. / Onteora High School  NaN
# 6001  NaN  Fr.       NaN              Hurley, N.Y. / Onteora  NaN
# 8221  NaN  Fr.  Distance  Hurley, N.Y. / Onteora High School  NaN
# 8266  NaN  So.  Distance   Hurley, N.Y. / Onteora Highschool  NaN
# 8313  NaN  Sr.  Distance              Hurley, N.Y. / Onteora  NaN
# 8355  NaN  Jr.  Distance              Hurley, N.Y. / Onteora  NaN
# 8448  NaN  Fr.  Distance   Hurley, N.Y. / Onteora Highschool  NaN
#
#                   Name                                          Name_link  \
# 5813  Emily Waligurski    /sports/w-xc/2014-15/bios/waligurski_emily_5lkl
# 5869  Emily Waligurski    /sports/w-xc/2016-17/bios/waligurski_emily_unhf
# 5950  Emily Waligurski    /sports/w-xc/2015-16/bios/waligurski_emily_9wvy
# 6001  Emily Waligurski    /sports/w-xc/2013-14/bios/waligurski_emily_hhnf
# 8221  Emily Waligurski  /sports/w-track/2012-13/bios/waligurski_emily_...
# 8266  Emily Waligurski  /sports/w-track/2014-15/bios/waligurski_emily_...
# 8313  Emily Waligurski  /sports/w-track/2016-17/bios/waligurski_emily_...
# 8355  Emily Waligurski  /sports/w-track/2015-16/bios/waligurski_emily_...
# 8448  Emily Waligurski  /sports/w-track/2013-14/bios/waligurski_emily_...
#
#       No. Pos. Weapon  Wt.   season          sport
# 5813  NaN  NaN    NaN  NaN  2014-15  Cross Country
# 5869  NaN  NaN    NaN  NaN  2016-17  Cross Country
# 5950  NaN  NaN    NaN  NaN  2015-16  Cross Country
# 6001  NaN  NaN    NaN  NaN  2013-14  Cross Country
# 8221  NaN  NaN    NaN  NaN  2012-13  Track & Field
# 8266  NaN  NaN    NaN  NaN  2014-15  Track & Field
# 8313  NaN  NaN    NaN  NaN  2016-17  Track & Field
# 8355  NaN  NaN    NaN  NaN  2015-16  Track & Field
# 8448  NaN  NaN    NaN  NaN  2013-14  Track & Field

# %%
# check which players are doing stuff every semester
pdf.groupby('Name').count().sort_values('Cl.', ascending=False).head(10)
# Out:
#                      B/T  Cl.  Events  Hometown/High School  Ht.  Name_link  \
# Name
# Emily Waligurski       0    9       5                     9    0          9
# Meredith Rizzo         0    9       5                     9    0          9
# Delaney FitzPatrick    0    8       4                     8    0          8
# Amanda Salvesen        0    8       0                     8    0          8
# Elizabeth McDonald     0    8       4                     8    0          8
# Andre Ivankovic        0    8       4                     8    0          8
# Chandler Olson         0    8       4                     8    0          8
# Duncan Tomlin          0    8       4                     8    0          8
# Jacob Sandry           0    8       4                     8    0          8
# Shannon McDonnell      0    8       4                     8    0          8
#
#                      No.  Pos.  Weapon  Wt.  season  sport
# Name
# Emily Waligurski       0     0       0    0       9      9
# Meredith Rizzo         0     0       0    0       9      9
# Delaney FitzPatrick    0     0       0    0       8      8
# Amanda Salvesen        0     0       0    0       8      8
# Elizabeth McDonald     0     0       0    0       8      8
# Andre Ivankovic        0     0       0    0       8      8
# Chandler Olson         0     0       0    0       8      8
# Duncan Tomlin          0     0       0    0       8      8
# Jacob Sandry           0     0       0    0       8      8
# Shannon McDonnell      0     0       0    0       8      8

# %%
def lookupPlayer(name):
    return pdf[pdf['Name'] == name]

# %%
# Who is a multi sport athlete?
pdf.groupby('Name')['sport'].nunique().sort_values(ascending=False).head(10)
# Out:
# Name
# Lindsey Raymond    3
# Jacque Sahlberg    3
# Conor Dooney       2
# Matt Chisholm      2
# Hannah Steffke     2
# Matt Bogdan        2
# Chris Stanley      2
# Sarah Smith        2
# Hannah Smith       2
# Kristin Johnson    2
# Name: sport, dtype: int64

# %%
# how many of these people are there?!
multis = pdf.groupby('Name')['sport'].nunique().sort_values(ascending=False)

# there were 246 multisport athletes! Their names can be 
multis = multis[multis >= 2]

# %%
multis.index
# Out:
# Index([u'Lindsey Raymond', u'Jacque Sahlberg', u'Conor Dooney',
#        u'Matt Chisholm', u'Hannah Steffke', u'Matt Bogdan', u'Chris Stanley',
#        u'Sarah Smith', u'Hannah Smith', u'Kristin Johnson',
#        ...
#        u'Max Brown', u'Juan Wheat', u'Nathan Richards', u'Jeff Perrella',
#        u'Morgan Kiss', u'Urska Kosir', u'Grace Zimmerly', u'Alexa Chu',
#        u'Claire Huebner', u'Grace Brittan'],
#       dtype='object', name=u'Name', length=246)

# %%
# we need to make a separate table for when each of these people started yale so you can ask if there's a pattern to this!

# %%
lookupPlayer("Lindsey Raymond")
# Out:
#       B/T       Cl.    Events  \
# 5977  NaN       Sr.       NaN
# 7272  NaN  Freshman       NaN
# 8396  NaN       Sr.  Distance
#
#                                    Hometown/High School  Ht.             Name  \
# 5977  Acton, Mass. / Acton-Boxborough Regional High ...  NaN  Lindsey Raymond
# 7272                       Acton, MA / Acton Boxborough  5-8  Lindsey Raymond
# 8396  Acton, Mass. / Acton-Boxborough Regional High ...  NaN  Lindsey Raymond
#
#                                               Name_link  No. Pos. Weapon  Wt.  \
# 5977     /sports/w-xc/2011-12/bios/raymond_lindsey_ojqj  NaN  NaN    NaN  NaN
# 7272        /sports/w-soccer/mtt/raymond_lindsey00.html   19    M    NaN  NaN
# 8396  /sports/w-track/2011-12/bios/raymond_lindsey_fgqe  NaN  NaN    NaN  NaN
#
#        season          sport
# 5977  2011-12  Cross Country
# 7272  2008-09         Soccer
# 8396  2011-12  Track & Field

# %%
# We know his height from one sport
# he has different bios in different sports.
# this table is actually a "relational" table called "played". Every time someone plays in a season, they get an entry here.

# note that if the play every year, their bio might change from year to year. in some cases their major is added in their oldest bio.

lookupPlayer("Jacque Sahlberg")
# Out:
#       B/T       Cl.    Events  Hometown/High School  Ht.             Name  \
# 5730  NaN       Sr.       NaN  Boise, Idaho / Boise  NaN  Jacque Sahlberg
# 5979  NaN       Jr.       NaN  Boise, Idaho / Boise  NaN  Jacque Sahlberg
# 6024  NaN       So.       NaN  Boise, Idaho / Boise  NaN  Jacque Sahlberg
# 7275  NaN  Freshman       NaN     Boise, ID / Boise  5-5  Jacque Sahlberg
# 7482  NaN       So.       NaN     Boise, ID / Boise  5-5  Jacque Sahlberg
# 8400  NaN       Sr.  Distance  Boise, Idaho / Boise  NaN  Jacque Sahlberg
# 8487  NaN       Jr.  Distance  Boise, Idaho / Boise  NaN  Jacque Sahlberg
#
#                                               Name_link  No. Pos. Weapon  Wt.  \
# 5730     /sports/w-xc/2012-13/bios/sahlberg_jacque_d63t  NaN  NaN    NaN  NaN
# 5979     /sports/w-xc/2011-12/bios/sahlberg_jacque_kiii  NaN  NaN    NaN  NaN
# 6024     /sports/w-xc/2010-11/bios/sahlberg_jacque_kiii  NaN  NaN    NaN  NaN
# 7275        /sports/w-soccer/mtt/sahlberg_jacque00.html   24    D    NaN  NaN
# 7482  /sports/w-soccer/2009-10/bios/sahlberg_jacque0...   24    D    NaN  NaN
# 8400  /sports/w-track/2011-12/bios/sahlberg_jacque_g31m  NaN  NaN    NaN  NaN
# 8487  /sports/w-track/2010-11/bios/sahlberg_jacque_g31m  NaN  NaN    NaN  NaN
#
#        season          sport
# 5730  2012-13  Cross Country
# 5979  2011-12  Cross Country
# 6024  2010-11  Cross Country
# 7275  2008-09         Soccer
# 7482  2009-10         Soccer
# 8400  2011-12  Track & Field
# 8487  2010-11  Track & Field

# %%
pdf['Hometown/Region'], pdf['High School'] = zip(*pdf['Hometown/High School'].apply(lambda x: x.split(" / ")))

# %%
def splitCityReg(string):
    if string == "-":
        return ["-", "-"]
    else:
        
        pair = string.split(", ")
        if len(pair) is 2:
            return pair
        else:
            return [string,'NOREGION?']

# %%
pdf['City'], pdf['Region'] = zip(*pdf['Hometown/Region'].apply(lambda x: splitCityReg(x) ))

# %%
m_cities_regs = pdf.groupby('Hometown/Region')['Name'].nunique().sort_values(ascending=False)
m_cities_regs
# Out:
# Hometown/Region
# New York, N.Y.                 45
# Greenwich, Conn.               25
# -                              24
# Los Angeles, Calif.            22
# Dallas, TX                     21
# Washington, D.C.               19
# San Francisco, Calif.          17
# San Diego, Calif.              16
# Baltimore, Md.                 15
# Boston, Mass.                  15
# Los Angeles, CA                13
# Seattle, WA                    13
# Seattle, Wash.                 12
# Houston, Texas                 12
# Pittsburgh, PA                 11
# St. Louis, Mo.                 11
# Newport Beach, Calif.          11
# Portland, OR                   11
# Cincinnati, OH                 11
# Greenwich, CT                  10
# Darien, Conn.                  10
# Newton, Mass.                  10
# Dallas, Texas                  10
# London, United Kingdom          9
# Manhasset, N.Y.                 9
# Palo Alto, Calif.               9
# Bronxville, N.Y.                9
# New Haven, Conn.                9
# Alexandria, VA                  8
# Arlington, Va.                  8
#                                ..
# Northbrook, IL                  1
# Norwalk, Conn.                  1
# Norwell, MA                     1
# Norwell, Mass.                  1
# Nottingham, England             1
# North Branford, Conn.           1
# North Andover, MA               1
# New York City                   1
# Newcastle, U.K.                 1
# New York City, N.Y.             1
# New York City, NY               1
# Newark, DE                      1
# Newark, Del.                    1
# Newark, N.J.                    1
# Newberry, Fla.                  1
# Newbury Park, CA                1
# Newbury, United Kingdom         1
# Newcastle, England              1
# Newnan, GA                      1
# Norman, OK                      1
# Newport Coast, CA               1
# Newtown Square, PA              1
# Newtown, Pa.                    1
# Niagara-on-the-Lake, Canada     1
# Nicosia, Cyprus                 1
# Nivot, Colo.                    1
# Nobleton, Ont.                  1
# Nolensville, Tenn.              1
# Norfolk, Va.                    1
# Manteca, Calif.                 1
# Name: Name, dtype: int64

# %%
m_school = pdf.groupby('High School')['Name'].nunique().sort_values(ascending=False)
m_school
# Out:
# High School
# -                                  44
# Deerfield Academy                  19
# New Trier                          18
# Chaminade                          18
# Phillips Exeter                    16
# Phillips Exeter Academy            16
# Choate Rosemary Hall               13
# Greenwich Academy                  12
# The Lawrenceville School           12
# The Pingry School                  12
# University                         12
# Buckingham Browne & Nichols        11
# Manhasset                          11
# Harvard-Westlake                   10
# Phillips Academy                   10
# St. Ignatius                        9
# Bronxville                          9
# Thomas Jefferson                    9
# Brunswick                           8
# Deerfield                           8
# Darien                              8
# Harvard Westlake                    8
# Hopkins School                      8
# Hotchkiss School                    8
# Phillips Academy Andover            8
# Lawrenceville                       8
# Loyola Academy                      8
# Groton School                       7
# Milton Academy                      7
# Montgomery Bell Academy             7
#                                    ..
# Mark Keppel High School             1
# Markham District                    1
# Marlborough                         1
# St. Mark                            1
# St. Margaret's                      1
# Martin County High School           1
# Martin Luther King                  1
# Manchester Essex                    1
# Mamaroneck High School              1
# Lycee Francois 1 er                 1
# Madison HS                          1
# Lycee Francois 1er                  1
# Lycee-College des Creusets          1
# Lyman Hall                          1
# Lyme-Old Lyme                       1
# Lynbrook                            1
# MICDS                               1
# Madera HS                           1
# St. Mildred’s Lightbourn            1
# St. Mary's of Annapolis             1
# Mamaroneck                          1
# Mahindra UWC (India)                1
# Mahindra UWC of India               1
# Mahopac                             1
# Mahwah                              1
# Maine South                         1
# Maine-Endwell                       1
# St. Mary's Prep - Orchard Lakes     1
# St. Mary's                          1
# Marjory Stoneman Douglas            1
# Name: Name, dtype: int64

# %%
pdf['Hometown/Region'][0].split(",")
# Out:
# [u'Manhasset', u' N.Y.']

# %%
m_city = pdf.groupby('City')['Name'].nunique().sort_values(ascending=False)
m_city
# Out:
# City
# New York               53
# Los Angeles            35
# Greenwich              31
# Dallas                 26
# Seattle                25
# -                      24
# San Diego              24
# Washington             22
# London                 21
# San Francisco          21
# Houston                19
# Baltimore              17
# Portland               17
# Boston                 16
# St. Louis              16
# Darien                 16
# Weston                 15
# Pittsburgh             14
# Palo Alto              13
# Nashville              13
# Bronxville             13
# Newton                 13
# Chicago                13
# Cincinnati             13
# Newport Beach          13
# Bethesda               13
# Honolulu               12
# Alexandria             12
# Garden City            11
# Tampa                  11
#                        ..
# Nashua                  1
# Nassau                  1
# North Babylon           1
# Norman                  1
# Norfolk                 1
# Nolensville             1
# Nobleton                1
# Nivot                   1
# Nicosia                 1
# Niagara-on-the-Lake     1
# Newtown                 1
# Newport Coast           1
# Newnan                  1
# Newbury Park            1
# Newbury                 1
# Newberry                1
# New Rochelle            1
# New Preston             1
# New London              1
# New Fairfield           1
# New Delhi               1
# New Braunfels           1
# New Bern                1
# New Berlin              1
# Nesconset               1
# Nepean                  1
# Needham                 1
# Nazareth                1
# Nassau County           1
# Margate                 1
# Name: Name, dtype: int64

# %%
m_reg = pdf.groupby('Region')['Name'].nunique().sort_values(ascending=False)
m_reg
# Out:
# Region
# Calif.           262
# N.Y.             200
# CA               175
# Mass.            141
# N.J.             137
# Conn.            123
# CT               112
# NY               107
# Pa.               82
# NJ                81
# Ill.              76
# MA                75
# TX                74
# Md.               67
# PA                65
# Fla.              61
# IL                60
# Texas             52
# Va.               50
# FL                49
# OH                45
# MD                44
# WA                40
# Wash.             39
# Mich.             37
# NOREGION?         34
# VA                30
# Ont.              26
# MI                26
# -                 24
#                 ...
# Israel             1
# Calif              1
# Nigeria            1
# Kans.              1
# MAN                1
# Il.                1
# MT                 1
# Ma.                1
# I.L.               1
# Massachusetts      1
# Mexico             1
# Miss.              1
# N.S.               1
# Florida            1
# New York           1
# F.L.               1
# California         1
# Estonia            1
# Nova Scotia        1
# Oh.                1
# P.A.               1
# Qu&eacute;.        1
# Cyprus             1
# Ct                 1
# Croatia            1
# Colorado           1
# Iowa               1
# Co.                1
# SK                 1
#  CA                1
# Name: Name, dtype: int64

# %%
pdf[pdf['Region'] == "NOREGION?"].head(20)
# Out:
#       B/T        Cl. Events  \
# 861   NaN        So.    NaN
# 894   NaN        Sr.    NaN
# 985   NaN        Jr.    NaN
# 1069  NaN        Fr.    NaN
# 1100  NaN        Jr.    NaN
# 1203  NaN        Fr.    NaN
# 1335  NaN   Freshman    NaN
# 1349  NaN     Junior    NaN
# 1352  NaN  Sophomore    NaN
# 1358  NaN  Sophomore    NaN
# 1372  NaN     Senior    NaN
# 1374  NaN   Freshman    NaN
# 1387  NaN     Senior    NaN
# 1391  NaN     Junior    NaN
# 1424  NaN  Sophomore    NaN
# 1428  NaN   Freshman    NaN
# 1435  NaN   Freshman    NaN
# 1696  NaN        So.    NaN
# 1754  NaN        Fr.    NaN
# 2078  NaN        So.    NaN
#
#                                    Hometown/High School  Ht.             Name  \
# 861      St. Catharines, Ont., Canada / Governor Simcoe  NaN      Aaron Jones
# 894      St. Catharines, Ont., Canada / Governor Simcoe  NaN      Aaron Jones
# 985      St. Catharines, Ont., Canada / Governor Simcoe  NaN      Aaron Jones
# 1069     St. Catharines, Ont., Canada / Governor Simcoe  NaN      Aaron Jones
# 1100     Lebanon. N.H. / International School of Manila  NaN    Regina DeLuna
# 1203            San Diego / University City High School  NaN    Allen Siegler
# 1335            New York / Bronx High School of Science  NaN     Jin Ishizuka
# 1349            New York / Bronx High School of Science  NaN     Jin Ishizuka
# 1352                   Los Angeles / Loyola High School  NaN   Frederick Muth
# 1358  San Francisco / San Francisco University High ...  NaN      Jacob Stein
# 1372                   Los Angeles / Loyola High School  NaN   Frederick Muth
# 1374  Washington D.C. / Washington International School  NaN  Isaac Shelanski
# 1387            New York / Bronx High School of Science  NaN     Jin Ishizuka
# 1391                   Los Angeles / Loyola High School  NaN   Frederick Muth
# 1424            New York / Bronx High School of Science  NaN     Jin Ishizuka
# 1428                   Los Angeles / Loyola High School  NaN   Frederick Muth
# 1435  San Francisco / San Francisco University High ...  NaN      Jacob Stein
# 1696                    Slate Hill NY / Minisink Valley  6-0    Kyle Cazzetta
# 1754                      Woodland Hills CA / Chaminade  6-1      Logan Scott
# 2078           Grosse, Pointe, MI / Grosse Pointe South  6-6     Marty Moesta
#
#                                              Name_link  No. Pos.       Weapon  \
# 861     /sports/m-crewlt/2014-15/bios/jones_aaron_shcw  NaN  NaN          NaN
# 894     /sports/m-crewlt/2016-17/bios/jones_aaron_atfu  NaN  NaN          NaN
# 985     /sports/m-crewlt/2015-16/bios/jones_aaron_8tmt  NaN  NaN          NaN
# 1069    /sports/m-crewlt/2013-14/bios/jones_aaron_g4f2  NaN  NaN          NaN
# 1100  /sports/m-crewlt/2010-11/bios/deluna_regina_zexq  NaN  NaN          NaN
# 1203      /sports/m-xc/2016-17/bios/siegler_allen_p2b5  NaN  NaN          NaN
# 1335     /sports/m-fenc/2012-13/bios/ishizuka_jin_zr5g  NaN  NaN         Foil
# 1349     /sports/m-fenc/2014-15/bios/ishizuka_jin_v90n  NaN  NaN         Foil
# 1352   /sports/m-fenc/2014-15/bios/muth_frederick_kkp1  NaN  NaN         Épée
# 1358      /sports/m-fenc/2014-15/bios/stein_jacob_ntuq  NaN  NaN  Foil, Sabre
# 1372   /sports/m-fenc/2016-17/bios/muth_frederick_vwlz  NaN  NaN         Épée
# 1374  /sports/m-fenc/2016-17/bios/shelanski_isaac_m2g3  NaN  NaN         Epee
# 1387     /sports/m-fenc/2015-16/bios/ishizuka_jin_16fv  NaN  NaN         Foil
# 1391   /sports/m-fenc/2015-16/bios/muth_frederick_ry4t  NaN  NaN         Épée
# 1424     /sports/m-fenc/2013-14/bios/ishizuka_jin_5jj2  NaN  NaN         Foil
# 1428   /sports/m-fenc/2013-14/bios/muth_frederick_ulo3  NaN  NaN         Épée
# 1435      /sports/m-fenc/2013-14/bios/stein_jacob_qu09  NaN  NaN  Foil, Sabre
# 1696  /sports/m-footbl/2012-13/bios/cazzetta_kyle_3fxn   37  K/P          NaN
# 1754    /sports/m-footbl/2012-13/bios/scott_logan_n1xb   14   QB          NaN
# 2078   /sports/m-footbl/2014-15/bios/moesta_marty_nlp2   99   DE          NaN
#
#       Wt.   season               sport               Hometown/Region  \
# 861   NaN  2014-15  Crew (Lightweight)  St. Catharines, Ont., Canada
# 894   NaN  2016-17  Crew (Lightweight)  St. Catharines, Ont., Canada
# 985   NaN  2015-16  Crew (Lightweight)  St. Catharines, Ont., Canada
# 1069  NaN  2013-14  Crew (Lightweight)  St. Catharines, Ont., Canada
# 1100  NaN  2010-11  Crew (Lightweight)                 Lebanon. N.H.
# 1203  NaN  2016-17       Cross Country                     San Diego
# 1335  NaN  2012-13             Fencing                      New York
# 1349  NaN  2014-15             Fencing                      New York
# 1352  NaN  2014-15             Fencing                   Los Angeles
# 1358  NaN  2014-15             Fencing                 San Francisco
# 1372  NaN  2016-17             Fencing                   Los Angeles
# 1374  NaN  2016-17             Fencing               Washington D.C.
# 1387  NaN  2015-16             Fencing                      New York
# 1391  NaN  2015-16             Fencing                   Los Angeles
# 1424  NaN  2013-14             Fencing                      New York
# 1428  NaN  2013-14             Fencing                   Los Angeles
# 1435  NaN  2013-14             Fencing                 San Francisco
# 1696  208  2012-13            Football                 Slate Hill NY
# 1754  187  2012-13            Football             Woodland Hills CA
# 2078  254  2014-15            Football            Grosse, Pointe, MI
#
#                                High School                          City  \
# 861                        Governor Simcoe  St. Catharines, Ont., Canada
# 894                        Governor Simcoe  St. Catharines, Ont., Canada
# 985                        Governor Simcoe  St. Catharines, Ont., Canada
# 1069                       Governor Simcoe  St. Catharines, Ont., Canada
# 1100        International School of Manila                 Lebanon. N.H.
# 1203           University City High School                     San Diego
# 1335          Bronx High School of Science                      New York
# 1349          Bronx High School of Science                      New York
# 1352                    Loyola High School                   Los Angeles
# 1358  San Francisco University High School                 San Francisco
# 1372                    Loyola High School                   Los Angeles
# 1374       Washington International School               Washington D.C.
# 1387          Bronx High School of Science                      New York
# 1391                    Loyola High School                   Los Angeles
# 1424          Bronx High School of Science                      New York
# 1428                    Loyola High School                   Los Angeles
# 1435  San Francisco University High School                 San Francisco
# 1696                       Minisink Valley                 Slate Hill NY
# 1754                             Chaminade             Woodland Hills CA
# 2078                   Grosse Pointe South            Grosse, Pointe, MI
#
#          Region
# 861   NOREGION?
# 894   NOREGION?
# 985   NOREGION?
# 1069  NOREGION?
# 1100  NOREGION?
# 1203  NOREGION?
# 1335  NOREGION?
# 1349  NOREGION?
# 1352  NOREGION?
# 1358  NOREGION?
# 1372  NOREGION?
# 1374  NOREGION?
# 1387  NOREGION?
# 1391  NOREGION?
# 1424  NOREGION?
# 1428  NOREGION?
# 1435  NOREGION?
# 1696  NOREGION?
# 1754  NOREGION?
# 2078  NOREGION?

# %%
# if you're in canada, you get your country and your province
# sometimes people just leave the state off.

# this data should probably be cleaned by hand!
# people from big cities tend to leave the state off

# %%
EXPORT_PLAYERS = os.path.join(PROJ_ROOT, 'data', 'interim', 'players.json')
EXPORT_ROSTERS = os.path.join(PROJ_ROOT, 'data', 'interim', 'rosters.p')

# %%
pdf.to_json(EXPORT_PLAYERS)

# %%
rdf = pd.DataFrame(rosters)

# %%
# verify later that tables are the same across all years for any given sport.
rdf.shape
rdf.head()
# Out:
#                                             metadata  \
# 0  [No., Name, Pos., Cl., B/T, Ht., Wt., Hometown...
# 1  [No., Name, Pos., Cl., B/T, Ht., Wt., Hometown...
# 2  [No., Name, Pos., Cl., B/T, Ht., Wt., Hometown...
# 3  [No., Name, Pos., Cl., B/T, Ht., Wt., Hometown...
# 4  [No., Name, Pos., Cl., B/T, Ht., Wt., Hometown...
#
#                                              players   season     sport
# 0  [{u'Pos.': u'C', u'No.': u'11', u'Name_link': ...  2008-09  Baseball
# 1  [{u'Pos.': u'IF/OF', u'No.': u'4', u'Name_link...  2012-13  Baseball
# 2  [{u'Pos.': u'RHP', u'No.': u'12', u'Name_link'...  2014-15  Baseball
# 3  [{u'Pos.': u'IF/OF', u'No.': u'1', u'Name_link...  2016-17  Baseball
# 4  [{u'Pos.': u'IF', u'No.': u'1', u'Name_link': ...  2009-10  Baseball

# %%
# This is going to be somewhat space inefficient for now, but it's OK
rdf.to_pickle(EXPORT_ROSTERS)

# %% [markdown]
# ### Next steps
#
# - we have a 'played' database with links to bios
# - we need to figure out what a unique player is
# - we need to unify their metadata
# - there is data to parse from each of their bios
# - Maybe there is text analysis to be done from their season-to-season-development
# - there is entity resolution to be done with hometowns and high schools.
