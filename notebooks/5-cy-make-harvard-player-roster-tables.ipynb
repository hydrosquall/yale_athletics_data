# %% [markdown]
# ## Notebook Overview
#
# Take the data from notebook 4, and flatten the nested data structures so it can be put into sql-database-friendly form.

# %%
# Use w/ Anaconda Distribution
# For data manipulation
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
PROJ_ROOT = os.pardir

# For Scraping
from bs4 import BeautifulSoup
import requests
import time

# For munging
import re
import json

# Backoff time for large scrapes
THROTTLE_TIME = .05

# ipython magics
# %load_ext watermark
# %matplotlib inline

# %%
import missingno as msno

# %%
# %watermark -a "Cameron Yick" -d -t -v -p pandas,seaborn,matplotlib,bs4 -g
# Out:
# Cameron Yick 2016-11-22 20:45:50
#
# CPython 2.7.12
# IPython 5.1.0
#
# pandas 0.18.1
# seaborn 0.7.1
# matplotlib 1.5.3
# bs4 4.5.1
# Git hash: 5843cde364ea00571b167c2c7dcfb5669ce09f28

# %%
RAW_PATH = os.path.join(PROJ_ROOT, "data", "raw", "sports.json")
RAW_PICK = os.path.join(PROJ_ROOT, "data", "raw", "harvard_sports.p")

# %%
sports = pd.read_pickle(RAW_PICK)

# %% [markdown]
# ## Can we check how the size of a roster has changed each year, for each sport?
#
# A roster is a collection of players for 1 season.

# %%
sports.columns
# Out:
# Index([u'rosters', u'sportCode', u'nSeasons'], dtype='object')

# %% [markdown]
# We have 36 collections of rosters, 1 for each sport. on at least 4 of those rosters, both genders are mixed together. (There may be other cases, such as female coxswains in on male crew boats).

# %%
len(sports)
# Out:
# 36

# %%
sports.rosters
# Out:
# 0     {u'2008-09': [[{'link': '/sports/bsb/2008-09/r...
# 1     {u'1989-90': [[{'link': '/sports/mbkb/1989-90/...
# 2     {u'2008-09': [[{'link': '/sports/mcrew-hw/2008...
# 3     {u'2008-09': [[{'link': '/sports/mcrew-lw/2008...
# 4     {u'2008-09': [[{'link': '/sports/xc/2008-09/ro...
# 5     {u'2008-09': [[{'link': '/sports/mfencing/2008...
# 6     {u'2008-09': [[{'link': '/sports/fball/2008-09...
# 7     {u'2008-09': [[{'link': '/sports/mgolf/2008-09...
# 8     {u'2008-09': [[{'link': '/sports/mice/2008-09/...
# 9     {u'2008-09': [[{'link': '/sports/mlax/2008-09/...
# 10    {u'2008-09': [[{'link': '/sports/sailing/2008-...
# 11    {u'2015-16': [[{'link': '/sports/skiing/2015-1...
# 12    {u'2016-17': [[{'link': '/sports/msoc/2016-17/...
# 13    {u'2008-09': [[{'link': '/sports/msquash/2008-...
# 14    {u'2008-09': [[{'link': '/sports/mswimdive/200...
# 15    {u'2008-09': [[{'link': '/sports/mten/2008-09/...
# 16    {u'2008-09': [[{'link': '/sports/track/2008-09...
# 17    {u'2008-09': [[{'link': '/sports/mvball/2008-0...
# 18    {u'2008-09': [[{'link': '/sports/mwaterpolo/20...
# 19    {u'2008-09': [[{'link': '/sports/wrest/2008-09...
# 20    {u'1989-90': [[{'link': '/sports/wbkb/1989-90/...
# 21    {u'2008-09': [[{'link': '/sports/wcrew-hw/2008...
# 22    {u'2008-09': [[{'link': '/sports/wcrew-lw/2008...
# 24    {u'2008-09': [[{'link': '/sports/wfencing/2008...
# 25    {u'2012-13': [[{'link': '/sports/fh/2012-13/ro...
# 26    {u'2008-09': [[{'link': '/sports/wgolf/2008-09...
# 27    {u'2012-13': [[{'link': '/sports/wice/2012-13/...
# 28    {u'2008-09': [[{'link': '/sports/wlax/2008-09/...
# 29    {u'2015-16': [[{'link': '/sports/wrugby/2015-1...
# 32    {u'2008-09': [[{'link': '/sports/wsoc/2008-09/...
# 33    {u'2008-09': [[{'link': '/sports/sball/2008-09...
# 34    {u'2008-09': [[{'link': '/sports/wsquash/2008-...
# 35    {u'2008-09': [[{'link': '/sports/wswimdive/200...
# 36    {u'2008-09': [[{'link': '/sports/wten/2008-09/...
# 38    {u'2012-13': [[{'link': '/sports/wvball/2012-1...
# 39    {u'2008-09': [[{'link': '/sports/wwaterpolo/20...
# Name: rosters, dtype: object

# %%
# The top entry for every table describes what metadata is available for players in that table.
sports.iloc[0]['rosters']['2015-16'][:1]
# Out:
# [[{'link': '/sports/bsb/2015-16/roster?sort=number', 'name': u'No.'},
#   {'link': '/sports/bsb/2015-16/roster?sort=last_name', 'name': u'Name'},
#   {'link': '/sports/bsb/2015-16/roster?sort=year', 'name': u'Yr.'},
#   {'link': '/sports/bsb/2015-16/roster?sort=position', 'name': u'Position'},
#   u'B/T',
#   u'Ht.',
#   u'Wt.',
#   u'Hometown',
#   u'High School']]

# %% [markdown]
# Before we can do anything fun, we need to attach these labels as keys onto the cell row entries.

# %%
def getFieldnames(rows):
    'Given an array of rows from a table, return a list of what to name all the keys in that table.'
    header = rows[0]
    names = []
    for fieldName in header:
        if type(fieldName) is dict:
            names.append(fieldName['name'])
        else:
            names.append(fieldName)
            
    return names

# %%
fish = getFieldnames(sports.iloc[32]['rosters']['2008-09'])
fish
# Out:
# [u'Name', u'Yr.', u'Event', u'Hometown', u'High School']

# %%
sports.iloc[32]['rosters']['2008-09'][1]
# Out:
# [u'',
#  {'link': '/sports/wswimdive/2008-09/bios/ash_marissa',
#   'name': u'Marissa Ash'},
#  u'Sophomore',
#  u'Diving',
#  u'Birmingham, Mich.',
#  u'Cranbrook Kingswood']

# %%
for i, val in enumerate(fish):
    print val
# Out:
# Name
# Yr.
# Event
# Hometown
# High School

# %%
# inexplicably, the headshot column sneaks into the table even though t
# the table header doesn't have a label for headshot!

# %%
# beware data issues: someone's weight entered as "20-0"
# http://www.gocrimson.com/sports/mbkb/1999-00/roster

# %%
rosters = []

for i, row in sports.iterrows(): # for each sport
    sportName = row['sportCode']
    
    for season, roster in row['rosters'].iteritems():    # check for each season
        nRoster = {}
        players = [] # new array of players for every season
        
        fieldNames = getFieldnames(roster)
        lenField = len(fieldNames)
           
        nRoster['sport'] = sportName             # this is the foreign key, when combined with the season
        nRoster['season'] = season
        nRoster['metadata'] = fieldNames
        
        # assumes that fieldnames are constant over all years for a given
        # sport.
        for person in roster[1:]: # skip over header row
            lenPerson = len(person)
            # iterate thru the tail rows of the roster, 
            nPlayer = {}
            nPlayer['sport'] = sportName
            nPlayer['season'] = season

            ## for each fieldname for the person
            for i, val in enumerate(fieldNames):
                if (lenField < lenPerson):
                    # for any sport with more cells than # of header labels
                    #, that means that a blank "picture" cell has been included.
                    #, and shoudl be skipped
                    fieldVal = person[i+1] # skip portrait
                else:
                    fieldVal = person[i]
    
                
                if type(fieldVal) is dict:
                    nPlayer[val + '_link'] = fieldVal['link']
                    nPlayer[val] = fieldVal['name']
                else:
                    nPlayer[val] = fieldVal
                    
            players.append(nPlayer)
        
        nRoster['players'] = players
        
        rosters.append(nRoster)

# %%
rosters[0]['players'][:2]
# Out:
# [{u'B/T': u'R/R',
#   u'High School': u'Woodrow Wilson',
#   u'Hometown': u'Long Beach, Calif.',
#   u'Ht.': u'6-2',
#   u'Name': u'Tyler Albright',
#   u'Name_link': '/sports/bsb/2008-09/bios/albright_tyler',
#   u'No.': u'6',
#   u'Position': u'C',
#   u'Wt.': u'190',
#   u'Yr.': u'Jr.',
#   'season': '2008-09',
#   'sport': 'bsb'},
#  {u'B/T': u'R/R',
#   u'High School': u'St. Stephens Episcopal',
#   u'Hometown': u'Austin, Texas',
#   u'Ht.': u'5-10',
#   u'Name': u'Cole Arledge',
#   u'Name_link': '/sports/bsb/2008-09/bios/arledge_cole',
#   u'No.': u'8',
#   u'Position': u'C',
#   u'Wt.': u'180',
#   u'Yr.': u'Jr.',
#   'season': '2008-09',
#   'sport': 'bsb'}]

# %%
len(rosters)
# Out:
# 426

# %%
players = []

for roster in rosters:
    players.extend(roster['players'])

# %%
len(players)
# Out:
# 10896

# %%
pdf = pd.DataFrame(players)

# %%
print pdf.columns
pdf.shape
# Out:
# Index([        u'B/T',       u'Event', u'High School',    u'Hometown',
#                u'Ht.',        u'Name',   u'Name_link',         u'No.',
#           u'Position',         u'S/C',      u'Weapon',         u'Wt.',
#                u'Yr.',      u'season',       u'sport'],
#       dtype='object')
# (10896, 15)

# %%
pdf.head()
# Out:
#    B/T Event             High School            Hometown   Ht.  \
# 0  R/R   NaN          Woodrow Wilson  Long Beach, Calif.   6-2
# 1  R/R   NaN  St. Stephens Episcopal       Austin, Texas  5-10
# 2  R/R   NaN                  Ramapo       Wyckoff, N.J.  5-11
# 3  R/R   NaN                Lakeside     Issaquah, Wash.   6-1
# 4  R/R   NaN         Lincoln-Sudbury      Sudbury, Mass.  5-10
#
#              Name                                Name_link No.  \
# 0  Tyler Albright  /sports/bsb/2008-09/bios/albright_tyler   6
# 1    Cole Arledge    /sports/bsb/2008-09/bios/arledge_cole   8
# 2     Dan Berardo     /sports/bsb/2008-09/bios/berardo_dan  10
# 3    Ian Bolliger    /sports/bsb/2008-09/bios/bolliger_ian  32
# 4       Adam Cole       /sports/bsb/2008-09/bios/cole_adam  11
#
#                Position  S/C Weapon  Wt.     Yr.   season sport
# 0                     C  NaN    NaN  190     Jr.  2008-09   bsb
# 1                     C  NaN    NaN  180     Jr.  2008-09   bsb
# 2                   RHP  NaN    NaN  180     Jr.  2008-09   bsb
# 3                   RHP  NaN    NaN  180     Sr.  2008-09   bsb
# 4  Right-Handed Pitcher  NaN    NaN  185  Senior  2008-09   bsb

# %%
# check which players are doing stuff every semester
pdf.groupby('Name').count().sort_values('sport', ascending=False).head(10)
# Out:
#                     B/T  Event  High School  Hometown  Ht.  Name_link  No.  \
# Name
# James Leakos          0      4            8         8    0          8    0
# Weishen Mead          0      4            8         8    0          8    0
# Jakob Lindaas         0      4            8         8    0          8    0
# Billy Looney          0      4            8         8    0          8    0
# Erik Kraus            0      4            8         8    0          8    0
# Darcy Wilson          0      4            8         8    0          8    0
# Aisha Price           0      0            8         8    4          8    8
# Connor Reck           0      4            8         8    0          8    0
# Stewart Richardson    0      4            8         8    0          8    0
# Kurt Ruegg            0      4            8         8    0          8    0
#
#                     Position  S/C  Weapon  Wt.  Yr.  season  sport
# Name
# James Leakos               0    0       0    0    8       8      8
# Weishen Mead               0    0       0    0    8       8      8
# Jakob Lindaas              0    0       0    0    8       8      8
# Billy Looney               0    0       0    0    8       8      8
# Erik Kraus                 0    0       0    0    8       8      8
# Darcy Wilson               0    0       0    0    8       8      8
# Aisha Price                8    0       0    0    8       8      8
# Connor Reck                0    0       0    0    8       8      8
# Stewart Richardson         0    0       0    0    8       8      8
# Kurt Ruegg                 0    0       0    0    8       8      8

# %%
def lookupPlayer(name):
    return pdf[pdf['Name'] == name]

# %%
# Who is a multi sport athlete?
pdf.groupby('Name')['sport'].nunique().sort_values(ascending=False).head(10)
# Out:
# Name
# Connor Green        3
# Jason Michas        2
# Dylan Trotzuk       2
# Jenn Hatfield       2
# Michael Hoffmann    2
# Michael Hoffman     2
# Tyler Cusick        2
# Connor Reck         2
# Catriona Stewart    2
# Jeffrey Homer       2
# Name: sport, dtype: int64

# %%
# how many of these people are there?!
multis = pdf.groupby('Name')['sport'].nunique().sort_values(ascending=False)

# there were 152 multisport athletes! Their names are
multis = multis[multis >= 2]

# %%
multis.shape
# Out:
# (152L,)

# %%
multis.index
# Out:
# Index([u'Connor Green', u'Jason Michas', u'Dylan Trotzuk', u'Jenn Hatfield',
#        u'Michael Hoffmann', u'Michael Hoffman', u'Tyler Cusick',
#        u'Connor Reck', u'Catriona Stewart', u'Jeffrey Homer',
#        ...
#        u'Johnny Marvin', u'Lukas Gemar', u'Brandon Price', u'Dan Stiles',
#        u'Jorie Sullivan', u'Grace Wagner', u'Maksim Korolev',
#        u'Will Battershill', u'Aaron Parker', u'Nicholas Linder'],
#       dtype='object', name=u'Name', length=152)

# %%
# we need to make a separate table for when each of these people started yale so you can ask if there's a pattern to this!

# %%
lookupPlayer("James Leakos")
# Out:
#       B/T     Event High School                 Hometown  Ht.          Name  \
# 2101  NaN       NaN  Holy Cross  Saskatoon, Saskatchewan  NaN  James Leakos
# 2233  NaN       NaN  Holy Cross  Saskatoon, Saskatchewan  NaN  James Leakos
# 2264  NaN       NaN  Holy Cross  Saskatoon, Saskatchewan  NaN  James Leakos
# 2297  NaN       NaN  Holy Cross  Saskatoon, Saskatchewan  NaN  James Leakos
# 6371  NaN  Distance  Holy Cross  Saskatoon, Saskatchewan  NaN  James Leakos
# 6733  NaN  Distance  Holy Cross  Saskatoon, Saskatchewan  NaN  James Leakos
# 6796  NaN  Distance  Holy Cross  Saskatoon, Saskatchewan  NaN  James Leakos
# 6895  NaN  Distance  Holy Cross  Saskatoon, Saskatchewan  NaN  James Leakos
#
#                                          Name_link  No. Position  S/C Weapon  \
# 2101      /sports/xc/2012-13/bios/men/leakos_james  NaN      NaN  NaN    NaN
# 2233     /sports/xc/2011-12/bios/mens/leakos_james  NaN      NaN  NaN    NaN
# 2264     /sports/xc/2013-14/bios/mens/leakos_james  NaN      NaN  NaN    NaN
# 2297     /sports/xc/2010-11/bios/Mens/leakos_james  NaN      NaN  NaN    NaN
# 6371   /sports/track/2012-13/bios/men/leakos_james  NaN      NaN  NaN    NaN
# 6733  /sports/track/2011-12/bios/mens/leakos_james  NaN      NaN  NaN    NaN
# 6796  /sports/track/2013-14/bios/mens/leakos_james  NaN      NaN  NaN    NaN
# 6895       /sports/track/2010-11/bios/leakos_james  NaN      NaN  NaN    NaN
#
#       Wt.        Yr.   season  sport
# 2101  NaN     Junior  2012-13     xc
# 2233  NaN  Sophomore  2011-12     xc
# 2264  NaN     Senior  2013-14     xc
# 2297  NaN   Freshman  2010-11     xc
# 6371  NaN     Junior  2012-13  track
# 6733  NaN  Sophomore  2011-12  track
# 6796  NaN     Senior  2013-14  track
# 6895  NaN   Freshman  2010-11  track

# %%
lookupPlayer("Connor Green")
# Out:
#       B/T    Event       High School         Hometown  Ht.          Name  \
# 2129  NaN      NaN  Pittsford Mendon  Pittsford, N.Y.  NaN  Connor Green
# 2202  NaN      NaN  Pittsford Mendon  Pittsford, N.Y.  NaN  Connor Green
# 5517  NaN   Nordic  Pittsford Mendon  Pittsford, N.Y.  NaN  Connor Green
# 5547  NaN   Nordic  Pittsford Mendon  Pittsford, N.Y.  NaN  Connor Green
# 5610  NaN   Nordic  Pittsford Mendon  Pittsford, N.Y.  NaN  Connor Green
# 6417  NaN  Steeple  Pittsford Mendon  Pittsford, N.Y.  NaN  Connor Green
#
#                                           Name_link  No. Position  S/C Weapon  \
# 2129      /sports/xc/2014-15/bios/mens/Green_Connor  NaN      NaN  NaN    NaN
# 2202      /sports/xc/2015-16/bios/Mens/Green_Connor  NaN      NaN  NaN    NaN
# 5517  /sports/skiing/2015-16/bios/green_connor_fl1v  NaN      NaN  NaN    NaN
# 5547  /sports/skiing/2016-17/bios/green_connor_w6af  NaN      NaN  NaN    NaN
# 5610  /sports/skiing/2014-15/bios/green_connor_9n64  NaN      NaN  NaN    NaN
# 6417   /sports/track/2014-15/bios/mens/Green_Connor  NaN      NaN  NaN    NaN
#
#       Wt.        Yr.   season   sport
# 2129  NaN   Freshman  2014-15      xc
# 2202  NaN  Sophomore  2015-16      xc
# 5517  NaN  Sophomore  2015-16  skiing
# 5547  NaN     Junior  2016-17  skiing
# 5610  NaN   Freshman  2014-15  skiing
# 6417  NaN   Freshman  2014-15   track

# %% [markdown]
# ### observation... harvard's multisport athletes are so far quite different from the yale combos
#
# - track + skiing + xc
# - sailing + squash

# %%
# We know his height from one sport
# he has different bios in different sports.
# this table is actually a "relational" table called "played". Every time someone plays in a season, they get an entry here.

# note that if the play every year, their bio might change from year to year. in some cases their major is added in their oldest bio.

lookupPlayer("Jason Michas")
# Out:
#       B/T Event        High School        Hometown  Ht.          Name  \
# 5357  NaN   NaN  Collegiate School  New York, N.Y.  NaN  Jason Michas
# 5404  NaN   NaN  Collegiate School  New York, N.Y.  NaN  Jason Michas
# 5448  NaN   NaN  Collegiate School  New York, N.Y.  NaN  Jason Michas
# 5496  NaN   NaN  Collegiate School  New York, N.Y.  NaN  Jason Michas
# 5688  NaN   NaN  Collegiate School  New York, N.Y.  NaN  Jason Michas
# 5741  NaN   NaN  Collegiate School  New York, N.Y.  NaN  Jason Michas
# 5776  NaN   NaN  Collegiate School  New York, N.Y.  NaN  Jason Michas
# 5824  NaN   NaN  Collegiate School  New York, N.Y.  NaN  Jason Michas
#
#                                            Name_link  No. Position  S/C  \
# 5357  /sports/sailing/2012-13/bios/mens/michas_jason  NaN      NaN  NaN
# 5404   /sports/sailing/2009-10/bios/men/michas_jason  NaN      NaN  NaN
# 5448  /sports/sailing/2011-12/bios/mens/michas_jason  NaN      NaN  NaN
# 5496  /sports/sailing/2010-11/bios/mens/michas_jason  NaN      NaN  NaN
# 5688  /sports/msquash/2012-13/bios/michas_jason_n2rj  NaN      NaN  NaN
# 5741       /sports/msquash/2009-10/bios/michas_jason  NaN      NaN  NaN
# 5776       /sports/msquash/2011-12/bios/michas_jason  NaN      NaN  NaN
# 5824       /sports/msquash/2010-11/bios/michas_jason  NaN      NaN  NaN
#
#      Weapon  Wt.        Yr.   season    sport
# 5357    NaN  NaN     Senior  2012-13  sailing
# 5404    NaN  NaN   Freshman  2009-10  sailing
# 5448    NaN  NaN     Junior  2011-12  sailing
# 5496    NaN  NaN  Sophomore  2010-11  sailing
# 5688    NaN  NaN     Senior  2012-13  msquash
# 5741    NaN  NaN   Freshman  2009-10  msquash
# 5776    NaN  NaN     Junior  2011-12  msquash
# 5824    NaN  NaN  Sophomore  2010-11  msquash

# %%
def splitCityReg(string):
    if string == "-":
        return ["-", "-"]
    else:
        
        pair = string.split(", ")
        if len(pair) is 2:
            return pair
        else:
            return [string,'NOREGION?']

# %%
pdf['City'], pdf['Region'] = zip(*pdf['Hometown'].apply(lambda x: splitCityReg(x) ))

# %% [markdown]
# Once again NY NY is top, but Houston in second is a surprise (possibly newton too?)

# %%
m_cities_regs = pdf.groupby('Hometown')['Name'].nunique().sort_values(ascending=False)
m_cities_regs
# Out:
# Hometown
#                                     94
# New York, N.Y.                      56
# Houston, Texas                      33
# Greenwich, Conn.                    28
# San Diego, Calif.                   28
# Newton, Mass.                       26
# San Francisco, Calif.               25
# London, England                     24
# Weston, Mass.                       24
# Toronto, Ont.                       23
# Palo Alto, Calif.                   23
# Atlanta, Ga.                        23
# Los Angeles, Calif.                 22
# Honolulu, Hawaii                    21
# Newport Beach, Calif.               21
# Washington, D.C.                    20
# Dallas, Texas                       20
# Cambridge, Mass.                    19
# Boston, Mass.                       19
# Chicago, Ill.                       19
# Brooklyn, N.Y.                      19
# Wellesley, Mass.                    19
# Seattle, Wash.                      17
# Austin, Texas                       16
# Belmont, Mass.                      16
# Garden City, N.Y.                   16
# Milton, Mass.                       15
# New Canaan, Conn.                   15
# Plano, Texas                        15
# Manhasset, N.Y.                     15
#                                     ..
# London, Ohio                         1
# South Freeport, Maine                1
# London, Ontario                      1
# London, United Kingdom               1
# Londonderry, N.H.                    1
# Londonderry, NH.                     1
# Lone Jack, Mo.                       1
# Liverpool, England                   1
# Livermore, Calif.                    1
# Littleton, N.H.                      1
# Lima, Ohio                           1
# Leonard, Mich.                       1
# Leonberg, Germany                    1
# Lewaood, Kan.                        1
# Lewisville, Texas                    1
# Southlake, Texas                     1
# Southbury, Conn.                     1
# Ligonier, Pa.                        1
# Southborough, Mass.                  1
# Limerick, Pa.                        1
# South Yarra, Australia               1
# Limon, Colo.                         1
# Lincoln Heights, Ohio                1
# Southampton, Pa.                     1
# Southampton, N.J.                    1
# Lincolnshire, England                1
# South Yarra, Victoria, Australia     1
# Lino Lakes, Minn.                    1
# Linwood, N.J.                        1
# Zurich, Switzerland                  1
# Name: Name, dtype: int64

# %%
## By school, exeter is at the top once again
## these queries can be rewritten using sql

# %%
m_school = pdf.groupby('High School')['Name'].nunique().sort_values(ascending=False)
m_school
# Out:
# High School
#                                   132
# Phillips Exeter Academy            35
# Deerfield Academy                  31
# Milton Academy                     23
# Belmont Hill School                19
# Phillips Academy Andover           17
# Boston Latin School                16
# Choate Rosemary Hall               16
# Weston                             15
# Delbarton School                   15
# Noble and Greenough School         14
# Groton School                      14
# Noble and Greenough                14
# Corona del Mar                     13
# Phillips Exeter Academy (N.H.)     13
# Phillips Academy                   13
# Garden City                        13
# Greenwich                          12
# Episcopal Academy                  12
# Brunswick School                   12
# Collegiate School                  12
# Jesuit                             12
# New Trier                          12
# St. Paul's                         11
# Manhasset                          11
# The Bishop's School                11
# Harvard-Westlake                   11
# Belmont Hill                       10
# Stuyvesant                          9
# St. Sebastian's School              9
#                                  ...
# Marriottsville Ridge                1
# St. Thomas More Collegiate          1
# St. Vincent-St. Mary                1
# Mahtomedi                           1
# Mamaroneck                          1
# Mahwah                              1
# Maiden                              1
# Maidstone Grammar                   1
# Maine Township South                1
# Mainland Regional                   1
# Malden                              1
# Malibu                              1
# Mallard Creek                       1
# Malmo Borgarskola                   1
# Malvern                             1
# Malvern Prep                        1
# Manalapan                           1
# Mar Vista                           1
# Manchester                          1
# Manchester Essex Regional           1
# Manchester Grammar                  1
# Mang'u                              1
# St. Xavier HS                       1
# Manheim Central                     1
# St. Wilfrid's Catholic              1
# Manlius                             1
# Mansfield                           1
# Maple Grove                         1
# Maple Grove Senior                  1
# Marling Grammar School              1
# Name: Name, dtype: int64

# %%
pdf['Hometown'][0].split(",")
# Out:
# [u'Long Beach', u' Calif.']

# %%
m_city = pdf.groupby('City')['Name'].nunique().sort_values(ascending=False)
m_city
# Out:
# City
#                      94
# New York             56
# Houston              34
# Toronto              29
# San Diego            29
# Weston               29
# Greenwich            28
# Newton               28
# London               28
# San Francisco        25
# Atlanta              23
# Los Angeles          23
# Palo Alto            23
# Dallas               22
# Chicago              21
# Newport Beach        21
# Cambridge            21
# Honolulu             21
# Washington           20
# Brooklyn             20
# Boston               20
# Wellesley            19
# Seattle              17
# Garden City          17
# Austin               16
# Lexington            16
# Belmont              16
# Baltimore            15
# New Canaan           15
# Pittsburgh           15
#                      ..
# Newton Center         1
# Newtown Square        1
# Niwot                 1
# No. Easton            1
# Norcross              1
# Norman                1
# Norridgewock          1
# North Attleboro       1
# New Fairfield         1
# New Britain           1
# Mount Laurel          1
# Nesconset             1
# Mount Pleasant        1
# Mountlake Terrace     1
# Mt. Juliet            1
# Mt. Vernon            1
# Mundelein             1
# Murfreesboro          1
# Muscat                1
# Muttontown            1
# Mystic                1
# N. Easton             1
# Nanuet                1
# Napa                  1
# Narberth              1
# Nashville             1
# Nassau                1
# Nazareth              1
# Needham,Mass.         1
# Zurich                1
# Name: Name, dtype: int64

# %%
# note the misspelling of sweeden (sic) and the doubling 
# of the number of people from california

# %%
m_reg = pdf.groupby('Region')['Name'].nunique().sort_values(ascending=False)
m_reg
# Out:
# Region
# Calif.          588
# Mass.           562
# N.Y.            411
# N.J.            208
# NOREGION?       190
# Conn.           163
# Texas           158
# Pa.             155
# Md.             135
# Fla.            128
# Ill.            114
# Ohio             94
# Ga.              86
# Minn.            80
# Va.              77
# Mich.            70
# Wash.            62
# England          62
# Ont.             52
# Colo.            43
# Ariz.            43
# N.C.             39
# Australia        38
# Mo.              32
# Ind.             32
# Hawaii           28
# N.H.             28
# Maine            26
# B.C.             25
# Vt.              25
#                ...
# Nevada            1
# Minn              1
# Saskatchewan      1
# Newfoundland      1
# S.K.              1
# Ore               1
# Québec            1
# Oreg.             1
# Pakistan          1
# N.B.              1
# Sweeden           1
# Ghana             1
# Ukraine           1
# Vt,               1
# Hawaii.           1
# Hong Kong         1
# Hungary           1
# IL.               1
# Iceland           1
# Ill               1
# UK                1
# Mi.               1
# Israel            1
# Kansas            1
# Kenya             1
# MD                1
# Trinidad          1
# Mass/             1
# Md                1
# texas             1
# Name: Name, dtype: int64

# %% [markdown]
# lots of missing data from the earlier harvard football folks, consider dropping them for fair comparison

# %%
pdf[pdf['Region'] == "NOREGION?"].head(20)
# Out:
#      B/T Event High School  Hometown  Ht.                  Name  \
# 310  NaN   NaN                                   Clifton Crosby
# 311  NaN   NaN                                     Edward Smith
# 312  NaN   NaN                                    Gerald Murphy
# 313  NaN   NaN                                     James Gabler
# 314  NaN   NaN                                    John Rockwell
# 315  NaN   NaN                                    Richard Covey
# 316  NaN   NaN                                  Robert Bramhall
# 317  NaN   NaN                                   William Hickey
# 318  NaN   NaN                                    William Prior
# 427  NaN   NaN   Sammamish  Bellevue  6-7      David Coatsworth
# 437  NaN   NaN                             Ambrose Redmond, Jr.
# 438  NaN   NaN                                  Edward Blodnick
# 439  NaN   NaN                                    Edward Condon
# 440  NaN   NaN                                   Edward Krinsky
# 441  NaN   NaN                                    Forest Hansen
# 442  NaN   NaN                                    Gerald Murphy
# 443  NaN   NaN                                   John Stevenson
# 444  NaN   NaN                                 Richard Lionette
# 445  NaN   NaN                                     Robert Gremp
# 446  NaN   NaN                                   William Dennis
#
#                                           Name_link No. Position  S/C Weapon  \
# 310        /sports/mbkb/1949-50/Bios/Clifton_Crosby      Forward  NaN    NaN
# 311          /sports/mbkb/1949-50/Bios/Edward_Smith      Forward  NaN    NaN
# 312         /sports/mbkb/1949-50/Bios/Gerald_Murphy        Guard  NaN    NaN
# 313          /sports/mbkb/1949-50/Bios/James_Gabler       Center  NaN    NaN
# 314         /sports/mbkb/1949-50/Bios/John_Rockwell      Forward  NaN    NaN
# 315         /sports/mbkb/1949-50/Bios/Richard_Covey        Guard  NaN    NaN
# 316       /sports/mbkb/1949-50/Bios/Robert_Bramhall        Guard  NaN    NaN
# 317        /sports/mbkb/1949-50/Bios/William_Hickey        Guard  NaN    NaN
# 318         /sports/mbkb/1949-50/Bios/William_Prior       Center  NaN    NaN
# 427      /sports/mbkb/1978-79/Bios/David_Coatsworth  12  Forward  NaN    NaN
# 437  /sports/mbkb/1951-52/Bios/Ambrose_Redmond-_Jr.      Forward  NaN    NaN
# 438       /sports/mbkb/1951-52/Bios/Edward_Blodnick       Center  NaN    NaN
# 439         /sports/mbkb/1951-52/Bios/Edward_Condon        Guard  NaN    NaN
# 440        /sports/mbkb/1951-52/Bios/Edward_Krinsky        Guard  NaN    NaN
# 441         /sports/mbkb/1951-52/Bios/Forest_Hansen      Forward  NaN    NaN
# 442         /sports/mbkb/1951-52/Bios/Gerald_Murphy      Forward  NaN    NaN
# 443        /sports/mbkb/1951-52/Bios/John_Stevenson      Forward  NaN    NaN
# 444      /sports/mbkb/1951-52/Bios/Richard_Lionette       Center  NaN    NaN
# 445          /sports/mbkb/1951-52/Bios/Robert_Gremp      Forward  NaN    NaN
# 446        /sports/mbkb/1951-52/Bios/William_Dennis        Guard  NaN    NaN
#
#      Wt.        Yr.   season sport      City     Region
# 310          Senior  1949-50  mbkb            NOREGION?
# 311          Junior  1949-50  mbkb            NOREGION?
# 312       Sophomore  1949-50  mbkb            NOREGION?
# 313          Junior  1949-50  mbkb            NOREGION?
# 314          Senior  1949-50  mbkb            NOREGION?
# 315          Senior  1949-50  mbkb            NOREGION?
# 316          Senior  1949-50  mbkb            NOREGION?
# 317       Sophomore  1949-50  mbkb            NOREGION?
# 318          Senior  1949-50  mbkb            NOREGION?
# 427  230   Freshman  1978-79  mbkb  Bellevue  NOREGION?
# 437          Senior  1951-52  mbkb            NOREGION?
# 438       Sophomore  1951-52  mbkb            NOREGION?
# 439       Sophomore  1951-52  mbkb            NOREGION?
# 440       Sophomore  1951-52  mbkb            NOREGION?
# 441          Junior  1951-52  mbkb            NOREGION?
# 442          Senior  1951-52  mbkb            NOREGION?
# 443          Senior  1951-52  mbkb            NOREGION?
# 444          Junior  1951-52  mbkb            NOREGION?
# 445       Sophomore  1951-52  mbkb            NOREGION?
# 446       Sophomore  1951-52  mbkb            NOREGION?

# %%
# if you're in canada, you get your country and your province
# sometimes people just leave the state off.

# this data should probably be cleaned by hand!
# people from big cities tend to leave the state off

# %%
EXPORT_PLAYERS = os.path.join(PROJ_ROOT, 'data', 'interim', 'harvard_players.json')
EXPORT_ROSTERS = os.path.join(PROJ_ROOT, 'data', 'interim', 'harvard_rosters.p')

# %%
pdf.to_json(EXPORT_PLAYERS)

# %%
rdf = pd.DataFrame(rosters)

# %%
rdf.shape
# Out:
# (426, 4)

# %%
# verify later that tables are the same across all years for any given sport.
rdf.head()
# Out:
#                                             metadata  \
# 0  [No., Name, Yr., Position, B/T, Ht., Wt., Home...
# 1  [No., Name, Yr., Position, B/T, Ht., Wt., Home...
# 2  [No., Name, Yr., Position, B/T, Ht., Wt., Home...
# 3  [No., Name, Yr., Position, B/T, Ht., Wt., Home...
# 4  [No., Name, Yr., Position, B/T, Ht., Wt., Home...
#
#                                              players   season sport
# 0  [{u'No.': u'6', u'Name_link': u'/sports/bsb/20...  2008-09   bsb
# 1  [{u'No.': u'20', u'Name_link': u'/sports/bsb/2...  2012-13   bsb
# 2  [{u'No.': u'20', u'Name_link': u'/sports/bsb/2...  2014-15   bsb
# 3  [{u'No.': u'1', u'Name_link': u'/sports/bsb/20...  2016-17   bsb
# 4  [{u'No.': u'6', u'Name_link': u'/sports/bsb/20...  2009-10   bsb

# %%
# This is going to be somewhat space inefficient for now, but it's OK
rdf.to_pickle(EXPORT_ROSTERS)

# %% [markdown]
# ### Next steps
#
# - we have a 'played' database with links to bios
# - we need to figure out what a unique player is
# - we need to unify their metadata
# - there is data to parse from each of their bios
# - Maybe there is text analysis to be done from their season-to-season-development
# - there is entity resolution to be done with hometowns and high schools.
